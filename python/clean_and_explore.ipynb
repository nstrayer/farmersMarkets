# %% [markdown]
# # Farmers Market Data!

# %%
# %pylab inline

import pandas as pd
import matplotlib.pyplot as plt
import os
from bokeh.plotting import figure, output_file, show
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['figure', 'show']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
data = pd.read_csv("../data/marketData.csv")

# %%
data.head()
# Out:
#       FMID                                       MarketName  \
# 0  1005969  "Y Not Wednesday Farmers Market at Town Center"
# 1  1008044                             10:10 Farmers Market
# 2  1000618                                  100-Mile Market
# 3  1002454                             112st Madison Avenue
# 4  1005586              12th & Brandywine Urban Farm Market
#
#                                              Website  \
# 0  http://www.sandlercenter.org/index/ynotwednesdays
# 1                   http://www.1010farmersmarket.com
# 2                   http://www.peoplesfoodco-op.org/
# 3                                                NaN
# 4                                                NaN
#
#                       street            city          County     State    zip  \
# 0         201 Market Street,  Virginia Beach  Virginia Beach  Virginia  23462
# 1       5960 Stewart Parkway    Douglasville         Douglas   Georgia  30135
# 2        507 Harrison Street       Kalamazoo       Kalamazoo  Michigan  49007
# 3       112th Madison Avenue        New York        New York  New York  10029
# 4  12th & Brandywine Streets      Wilmington      New Castle  Delaware  19801
#
#                 Season1Date                                   Season1Time  \
# 0            June to August                        Wed:5:00 PM - 8:00 PM;
# 1       January to December                        Thu:4:00 pm - 7:00 pm;
# 2  05/01/2013 to 10/30/2013                         Wed: 3:00 PM-7:00 PM;
# 3          July to November  Tue:8:00 am - 5:00 pm;Sat:8:00 am - 8:00 pm;
# 4  06/17/2013 to 10/14/2013                         Mon: 4:00 PM-7:00 PM;
#
#        ...       Meat Nursery Nuts Plants Poultry Prepared  Soap  Trees Wine  \
# 0      ...          N       N    N      N       N        Y     Y      N    Y
# 1      ...          Y       N    N      Y       N        Y     Y      N    N
# 2      ...          Y       N    N      Y       N        Y     N      N    N
# 3      ...          N       N    Y      N       N        Y     Y      N    N
# 4      ...          N       N    N      N       N        N     N      N    N
#
#       updateTime
# 0   5/5/12 17:56
# 1  7/18/12 13:51
# 2   7/1/13 23:29
# 3   3/1/12 10:38
# 4  6/13/13 13:33
#
# [5 rows x 45 columns]

# %% [markdown]
# ##Plotting
# Let's first try plotting with standard matplotlib

# %%
plt.scatter(data.x, data.y)

# %% [markdown]
# Now with Bokeh...

# %%
x = data.x
y = data.y

# output to static HTML file (with CDN resources)
output_file("color_scatter.html", title="color_scatter.py example", mode="cdn")

TOOLS="resize,crosshair,pan,wheel_zoom,box_zoom,reset,box_select,lasso_select"

# create a new plot with the tools above, and explicit ranges
p = figure(tools=TOOLS)
p.circle(x,y)
show(p)
